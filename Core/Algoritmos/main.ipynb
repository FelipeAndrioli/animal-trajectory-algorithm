# %%
import gdal
import affine
import numpy as np
import geopandas as gpd
import arcpy
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-25e85b583786> in <module>
#       3 import numpy as np
#       4 import geopandas as gpd
# ----> 5 import arcpy
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'arcpy'

# %%
def get_altitude(geo_coord, data_source):
    x, y = geo_coord[0], geo_coord[1]
    forward_transform = \
        affine.Affine.from_gdal(*data_source.GetGeoTransform())
    reverse_transform = ~forward_transform
    px, py = reverse_transform * (x, y)
    px, py = int(px + 0.5), int(py + 0.5)
    pixel_coord = px, py
    data_array = np.array(data_source.GetRasterBand(1).ReadAsArray())
    
    return data_array[pixel_coord[0]][pixel_coord[1]]

# %%
demdata = gdal.Open('./Shapefiles/ms.tif')
demarray = np.array(demdata.GetRasterBand(1).ReadAsArray())

# %%
coords = ((-55.109899, -20.418126))
get_altitude(coords, demdata)
# Out:
# 277

# %%
death_position_df = gpd.read_file('./Shapefiles/Amostras.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open ./Shapefiles/Amostras.shx or ./Shapefiles/Amostras.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-25-18fc56e457c7> in <module>
# ----> 1 death_position_df = gpd.read_file('./Shapefiles/Amostras.shp')
#
# C:\miniconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
#      78             # In a future Fiona release the crs attribute of features will
#
# ...
